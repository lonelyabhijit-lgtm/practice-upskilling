# %%
str_x = input("Enter a string: ")
for i in range(len(str_x)):
  print(str_x[:i+1])

# %%
try:    
    max_rows = int(input("Enter desired rows:"))
    if max_rows <= 0:
        print("Enter a valid positive integer")
    max_cols = max_rows * 2 - 1
    for i in range(max_rows):
        stars = " ".join("*" * (i+1))
        print(stars.center(max_cols))
except ValueError:
    print("Enter a valid positive integer")

# %%
str_x = input("Enter a string:")
for i in range(len(str_x)):
    print(' '.join(str_x[:i+1]).center(len(str_x)*2-1))

# %%
" ".join("*"*5).center(11)

# %%
rows = int(input("Enter number of rows: "))
for i in range(1, rows + 1):
    if i == 1:
        stars = "*"
    elif i == rows:
        stars = " ".join("*" * i)
    else:
        stars = "*" + " " * (2 * i - 3) + "*"
    print(stars.center(rows * 2 - 1))

# %%
str_x = input("Enter a string: ")
str_spaced = '*'.join(str_x)
print(str_spaced)

# %%
rows = int(input("Enter number of rows: "))
cols = int(input("Enter number of columns: "))
for _ in range(rows):
    print(" ".join("*" * cols))

# %%
rows = int(input("Enter number of rows: "))
cols = int(input("Enter number of columns: "))
for i in range(rows):
    if i == 0 or i == rows - 1:
        print(" ".join("*" * cols))
    else:
        print("*" + " " * (2 * cols - 3) + "*")

# %%
import math

radius = int(input("Enter radius: "))
diameter = radius * 2
for y in range(diameter + 1):
    row = ""
    for x in range(diameter + 1):
        dist = math.sqrt((x - radius) ** 2 + (y - radius) ** 2)
        if radius - 0.5 < dist < radius + 0.5:
            row += "*"
        else:
            row += " "
    print(row)

# %%
a = "a", "b", "c"
type(a)

# %%
5/2

# %%
5//2

# %%
for c in ['a','b','c','d']:
    print(c)

# %%
for c in {'a','b','c','d'}:
    print(c)

# %%
for c in ('a','b','c','d'):
    print(c)

# %%
ord('[')

# %%
letters = [chr(i) for i in range(ord('A'), ord('z') + 1)]
print(letters)

# %%
# Common emoji code points
emojis = [chr(128512), chr(128514), chr(10084), chr(128077), chr(127881), chr(128525), chr(128175), chr(128640), chr(127775), chr(128013)]

print("Emoji Code Points:")
print("-" * 50)
for emoji in emojis:
    code_point = ord(emoji)
    print(f"{emoji}  ->  {code_point:6d}  (0x{code_point:04X})")

print("\n" + "=" * 50)
print("Creating emojis from code points:")
print("=" * 50)

# Generate emojis from specific code points
code_points = [128512, 128151, 127881, 129412, 127775]
for cp in code_points:
    print(f"chr({cp}) = {chr(cp)}")

# %%
for i in range(ord('z')):
    print(chr(i))

# %%
chr(0)

# %%
# Default behavior - adds newline at end
print("Hello")
print("World")

print("\n" + "=" * 40 + "\n")

# Using end='' to print on same line
print("Hello", end='')
print("World")

print("\n" + "=" * 40 + "\n")

# Using end=' ' to separate with space
for i in range(5):
    print(i, end=' ')

print()  # Empty print to move to next line

print("\n" + "=" * 40 + "\n")

# Using custom end string
for char in "PYTHON":
    print(char, end='*')

print()  # Move to next line

# %%
5<=5+5

# %%
(5<=5)+5

# %%
a="%s is a number" %5
print(a)

# %%
15//10

# %%
5//10

# %%
list(zip(range(5),range(5)))

# %%
"apple".index('p')

# %%
s = "apple"
indices = [(char, idx) for idx, char in enumerate(s)]
display(indices)

# %%
[(char, idx) for idx, char in enumerate(s) if char=='p']

# %%
'*****' == '*'*5

# %%
str_updated = s
len_s = len(s)
int_try = 0
while str_updated != '*'*len_s:
    char_inp = input("Enter the character present in the word:")
    if char_inp in s:
        str_updated = str_updated.replace(char_inp,'*')
    else:
        print("Try again")
    int_try += 1
print("You have guessed the word %s in %d tries" %(s, int_try))

# %%
# %pip install nltk

# %%
# %restart_python

# %%
import nltk

# %%
nltk.download('wordnet')

# %%
from nltk.corpus import wordnet
import random

words =[x for x in list(set([w.name().split('.')[0] for w in wordnet.all_synsets()])) if '_' not in x]
random_words = random.sample(words, 10)
display(random_words)

# %%
abc = 'elephant'
index = 2  # example index
replacement = 'x'
abc = abc[:index] + replacement + abc[index+1:]
abc

# %%
lst_a = list(range(10))
lst_b = list(range(12))
list(zip(lst_a, lst_b))

# %%
lst_b

# %%
list(range(10,100,10))

# %%
lst_c = list(range(10))
print(*lst_c)

# %%
print(*tuple(range(10)))

# %%
print(*range(10))

# %%
tuple(*range(10))

# %%
print(**{'name':'John','age':28})

# %%
def student_details(**details):
    print(type(details))
    for k,v in details.items():
        print(k,v)

# %%
student_details(name='John',college='Columbia')

# %%
dict_a = {'name':'John','age':28}
student_details(**dict_a)

# %%
student_details(dict_a)
